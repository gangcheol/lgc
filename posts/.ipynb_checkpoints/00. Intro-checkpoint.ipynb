# %% [raw]
# ---
# title: "00. Intro"
# author: "LGC"
# date : "03/05/26"
# ---

# %% [markdown]
# # TEST

# %% [markdown]
# test 입니다.

# %% [markdown]
# $$\hat y = \beta_{1} x + \beta_{0},\quad  X \sim N(\mu, \sigma^2)$$
